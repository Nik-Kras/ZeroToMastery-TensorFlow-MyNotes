# %%
name = input("Say my name: ")

if name == "Heizenberg":
  print("You got damn right")
else:
  print("No")
# Out:
# Say my name: Heizenberg
# You got damn right

# %% [markdown]
# Тра ля ля, тру лю лю

# %%
a = 5
b = 10
c = pow(b,a)
print(c)
# Out:
# 100000
