# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('drive/MyDrive/Colab Notebooks/Udemy: TensorFlow')

# %%
# !ls
# Out:
# '01. Tensors'	  '03. Classification'	  README.md	      Test
# '02. Regression'  '04. Computer Vision'  'Set GitHub.ipynb'

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/Udemy: TensorFlow

# %%
# Run only to start from the beginning
git_token = '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'
username = 'Nik-Kras'
repository = 'ZeroToMastery-TensorFlow-MyNotes'

# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Cloning into 'ZeroToMastery-TensorFlow-MyNotes'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), done.

# %%
# !git status

# %%
# Run only if asked
# !git config --global user.email "19175127@brookes.ac.uk"
# !git config --global user.name "Nikita Krasnytskyi"

# %%
# !git add -A

# %%
# !git commit -m "Set the GitHub to Google Drive"
# Out:
# [main 0e7cba9] Set the GitHub to Google Drive
#  13 files changed, 16 insertions(+)
#  create mode 100644 01. Tensors/01_Tensors.ipynb
#  create mode 100644 02. Regression/02_Regression.ipynb
#  create mode 100644 02. Regression/saved_model/My_model_on_database/keras_metadata.pb
#  create mode 100644 02. Regression/saved_model/My_model_on_database/saved_model.pb
#  create mode 100644 02. Regression/saved_model/My_model_on_database/variables/variables.data-00000-of-00001
#  create mode 100644 02. Regression/saved_model/My_model_on_database/variables/variables.index
#  create mode 100644 03. Classification/03_Classification.ipynb
#  create mode 100644 04. Computer Vision/04. CV - Notes.ipynb
#  create mode 100644 04. Computer Vision/Copy of 03_convolutional_neural_networks_in_tensorflow.ipynb
#  create mode 100644 Set GitHub.ipynb
#  create mode 100644 Test/Test_1.ipynb
#  rename 04 Computer Vision.ipynb => ZeroToMastery-TensorFlow-MyNotes/04 Computer Vision.ipynb (100%)
#  rename My_note.ipynb => ZeroToMastery-TensorFlow-MyNotes/My_note.ipynb (100%)

# %%
# !git push
# Out:
# Counting objects: 22, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (19/19), done.
# Writing objects: 100% (22/22), 4.37 MiB | 7.01 MiB/s, done.
# Total 22 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/Nik-Kras/ZeroToMastery-TensorFlow-MyNotes
#    adf3848..0e7cba9  main -> main
